# %%
# Import pandas 
import pandas as pd

# Load the us health care data csv as a dataframe
file_name = "https://raw.githubusercontent.com/BuzzFeedNews/2017-05-us-health-care/master/data/OECD/health_spending_per_cap.csv"
df = pd.read_csv(file_name)

# Return the first couple of records (default is 5)
df.head()
# Out:
#   LOCATION  INDICATOR SUBJECT  MEASURE FREQUENCY  TIME     Value Flag Codes
# 0      AUS  HEALTHEXP     TOT  USD_CAP         A  1971  223.5920        NaN
# 1      AUS  HEALTHEXP     TOT  USD_CAP         A  1972  239.1784        NaN
# 2      AUS  HEALTHEXP     TOT  USD_CAP         A  1973  264.0303        NaN
# 3      AUS  HEALTHEXP     TOT  USD_CAP         A  1974  322.3286        NaN
# 4      AUS  HEALTHEXP     TOT  USD_CAP         A  1975  401.8512        NaN

# %%
# Similar to SELECT * FROM us_health_care WHERE LOCATION = 'USA'

USA = df.loc[df['LOCATION'] == 'USA']

# %%
USA
# Out:
#      LOCATION  INDICATOR SUBJECT  MEASURE FREQUENCY  TIME      Value  \
# 1139      USA  HEALTHEXP     TOT  USD_CAP         A  1970   326.9704
# 1140      USA  HEALTHEXP     TOT  USD_CAP         A  1971   357.9830
# 1141      USA  HEALTHEXP     TOT  USD_CAP         A  1972   397.1014
# 1142      USA  HEALTHEXP     TOT  USD_CAP         A  1973   439.3022
# 1143      USA  HEALTHEXP     TOT  USD_CAP         A  1974   495.1230
# 1144      USA  HEALTHEXP     TOT  USD_CAP         A  1975   560.7455
# 1145      USA  HEALTHEXP     TOT  USD_CAP         A  1976   638.8557
# 1146      USA  HEALTHEXP     TOT  USD_CAP         A  1977   726.2369
# 1147      USA  HEALTHEXP     TOT  USD_CAP         A  1978   808.8881
# 1148      USA  HEALTHEXP     TOT  USD_CAP         A  1979   908.9625
# 1149      USA  HEALTHEXP     TOT  USD_CAP         A  1980  1036.3091
# 1150      USA  HEALTHEXP     TOT  USD_CAP         A  1981  1191.5418
# 1151      USA  HEALTHEXP     TOT  USD_CAP         A  1982  1329.6731
# ...

# %%
USA.loc[df['Value'].idxmax()]
# Out:
# LOCATION            USA
# INDICATOR     HEALTHEXP
# SUBJECT             TOT
# MEASURE         USD_CAP
# FREQUENCY             A
# TIME               2015
# Value           9451.34
# Flag Codes            E
# Name: 1184, dtype: object
